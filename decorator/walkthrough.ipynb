# %% [markdown]
# # decorator 过程演示（离线 mock）
# 本 Notebook 按函数装饰器 -> 参数化装饰器 -> 类装饰器 -> 叠加调用链的顺序学习。

# %%
from decorator.component import CountCalls, run_demo, timed, with_tag

# %%
trace = []
"decorator 模块是固定教学案例，不依赖外部 prompt。"

# %%
@timed
def only_timed(x: float, *, _trace=None) -> float:
    return x * 2

t_trace = []
only_timed(3.0, _trace=t_trace), t_trace

# %%
@with_tag("billing")
def only_tag(x: float, *, _trace=None) -> float:
    return x + 1

tag_trace = []
only_tag(2.0, _trace=tag_trace), tag_trace

# %%
@CountCalls
def only_counter(x: float, *, _trace=None) -> float:
    return x

count_trace = []
only_counter(1.0, _trace=count_trace)
only_counter(2.0, _trace=count_trace)
only_counter.call_count, count_trace

# %%
@CountCalls
@with_tag("billing")
@timed
def stacked(subtotal: float, tax_rate: float, *, _trace=None) -> float:
    if _trace is not None:
        _trace.append({"event": "decorated_function_body", "subtotal": subtotal})
    return subtotal * (1 + tax_rate)

stack_trace = []
stacked(100.0, 0.1, _trace=stack_trace)
stack_trace

# %%
result = run_demo()\nresult["final_answer"], result["trace"]
