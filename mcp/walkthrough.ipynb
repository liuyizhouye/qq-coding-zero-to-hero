# %% [markdown]
# # MCP 在线审批过程演示
# 展示 `mcp_approval_request`、批准/拒绝分支与最终在线总结。

# %%
import os

from component import build_mcp_tool_config, request_mcp_approval_request, run_demo

if not os.getenv("DEEPSEEK_API_KEY"):
    raise RuntimeError("请先设置 DEEPSEEK_API_KEY")

# %%
user_text = "什么是 Model Context Protocol？"
tool_config = build_mcp_tool_config()
approval_request = request_mcp_approval_request(user_text, tool_config)
approval_request_id = approval_request["approval_request_id"]
tool_config, approval_request, approval_request_id

# %%
approved_result = run_demo(user_text, approve=True)
approved_result["final_answer"]

# %%
rejected_result = run_demo(user_text, approve=False)
rejected_result["final_answer"]

# %%
comparison = {
    "approved_events": [e["event"] for e in approved_result["trace"]],
    "rejected_events": [e["event"] for e in rejected_result["trace"]],
}
comparison

# %%
approved_result["trace"]

# %%
rejected_result["trace"]
