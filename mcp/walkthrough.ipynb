# %% [markdown]
# # MCP 审批过程演示（离线 mock）
# 展示 `mcp_approval_request`、批准/拒绝分支和状态变化。

# %%
import json
from component import build_mcp_tool_config, mock_mcp_approval_request, run_demo

# %%
tool_config = build_mcp_tool_config()
approval_request = mock_mcp_approval_request()
approval_request_id = approval_request["approval_request_id"]
tool_config, approval_request_id, approval_request

# %%
approved_result = run_demo("什么是 Model Context Protocol？", approve=True)
approved_result["final_answer"]

# %%
rejected_result = run_demo("什么是 Model Context Protocol？", approve=False)
rejected_result["final_answer"]

# %%
comparison = {
    "approved_events": [e["event"] for e in approved_result["trace"]],
    "rejected_events": [e["event"] for e in rejected_result["trace"]],
}
comparison

# %%
approved_result["trace"]

# %%
rejected_result["trace"]
