# %% [markdown]
# # openai_api walkthrough
#
# 目标：理解 OpenAI API 功能全景、关键参数、以及 DeepSeek 兼容实调结果。

# %%
from openai_api.component import build_capability_overview

overview = build_capability_overview()
for idx, item in enumerate(overview, start=1):
    print(f'[{idx}] {item["capability"]} -> {item["api_surface"]}')

# %%
from openai_api.component import build_parameter_reference

reference = build_parameter_reference()
for endpoint, payload in reference.items():
    print()
    print(f'=== {endpoint} ===')
    print('required:', payload['required_params'])
    print('core:', sorted(payload['core_params'].keys()))
    print('all count:', len(payload['all_param_names']))

# %%
from openai_api.component import run_demo

result = run_demo('请用简短中文说明 LLM API 常见能力与参数作用。')
for idx, event in enumerate(result['trace'], start=1):
    print(f'[{idx}] {event["event"]}')
print('FINAL:', result['final_answer'])
