# %% [markdown]
# # function_call 过程演示（离线 mock）
# 按顺序展示 `function_call -> 本地函数 -> function_call_output -> final_answer`。

# %%
import json
from component import calc_portfolio_value, mock_model_function_call, run_demo

# %%
user_text = "请计算组合总市值: AAPL 10@180.5, TSLA -3@210, SPY 2@500。请先调用工具再回答。"
user_text

# %%
call = mock_model_function_call(user_text)
call_id = call["call_id"]
arguments = call["arguments"]
print("call_id =", call_id)
print("arguments =", arguments)
call

# %%
parsed_arguments = json.loads(arguments)
positions = parsed_arguments["positions"]
local_result = calc_portfolio_value(positions)
positions, local_result

# %%
function_call_output = {
    "type": "function_call_output",
    "call_id": call_id,
    "output": json.dumps({"result": local_result}, ensure_ascii=False),
}
output = function_call_output["output"]
print("output =", output)
function_call_output

# %%
demo_result = run_demo(user_text)
demo_result["final_answer"]

# %%
demo_result["trace"]
